# %%
import matplotlib.pyplot as plt
import numpy as np


c_num_list = []
pkeoet_enc_list = []
pkeoet_ptest_list = []
pkeoet_total_list = []
pkeet_enc_list = []
dt_list = []
pkeet_t_list = []

pkeoet_log = 'output/log1.txt'
dt_log = 'output/log_d.txt'
pkeet_log = 'output/pkeet_log.txt'

# %%
c_num_list = []
pkeoet_enc_list = []
pkeoet_ptest_list = []
pkeoet_total_list = []

with open(pkeoet_log, 'r') as f1:
    for line in f1.readlines():
        if line[0] != 'C':
            l = line.split('\t')[:-1]
            c_num_list.append(int(l[0].split('.')[0]))
            pkeoet_enc_list.append(float(l[1]))
            pkeoet_ptest_list.append(float(l[2]))
            pkeoet_total_list.append(float(l[3]))

# with open(hg_log, 'r') as f2:
#     for line in f2.readlines():
#         if line[0] != 'E':
#             hg_val_list.append(float(line.split('\t')[-2]))
len(c_num_list)
# Out:
# 906

# %%
dt_list = []
with open(dt_log, 'r') as f2:
    for line in f2.readlines():
        if line[0] != 'V':
            l = line.split('\t')[:-1]
            num = int(l[0].split('.')[0])
            if num in c_num_list:
                dt_list.append(float(l[1]))
len(dt_list)
# Out:
# 906

# %%
# c_num_list = []
pkeet_enc_list = []
pkeet_t_list = []

with open(pkeet_log, 'r') as f3:
    for line in f3.readlines():
        if line[0] != 'C':
            l = line.split('\t')[:-1]
            num = int(l[0].split('.')[0])
            if num in c_num_list:
                pkeet_enc_list.append(float(l[1]))
                pkeet_t_list.append(float(l[2]))

len(pkeet_t_list)
# Out:
# 906

# %%
pkeet_enc_list
# Out:
# [0.305086,
#  0.611252,
#  0.91996,
#  1.224953,
#  1.529521,
#  3.061865,
#  4.59895,
#  6.145235,
#  9.240007,
#  12.294008,
#  15.350619,
#  18.400387,
#  21.447059,
#  24.498305,
#  27.554738,
#  30.61198,
#  33.666113,
#  36.716602,
#  39.764709,
#  42.817863,
#  45.868251,
#  48.921715,
#  51.972224,
#  55.026953,
#  58.077903,
#  61.132092,
#  64.186563,
#  67.237031,
#  70.28691,
#  73.345578,
#  76.394585,
#  79.455037,
#  82.501881,
#  85.558091,
#  88.607843,
#  91.664421,
#  94.714368,
#  97.767798,
#  100.8201,
#  103.876544,
#  106.932047,
#  109.985943,
#  113.035786,
#  116.089171,
#  119.139962,
#  122.198111,
#  125.24803,
#  128.307209,
#  131.361755,
#  134.415041,
#  137.465328,
#  140.517755,
#  143.573646,
#  146.620725,
#  149.671325,
#  152.729271,
#  155.785654,
#  158.840617,
#  161.894115,
#  164.95076,
#  167.999036,
#  171.054615,
#  174.107255,
#  177.156528,
#  180.207216,
#  183.261376,
#  186.30886,
#  189.363977,
#  192.413012,
#  195.468645,
#  198.521637,
#  201.573808,
#  204.624252,
#  207.676761,
#  210.729276,
#  213.783332,
#  216.837564,
#  219.88503,
#  222.935441,
#  225.991401,
#  229.040377,
#  232.098517,
#  235.151917,
#  238.20612,
#  241.260962,
#  244.317532,
#  247.372373,
#  250.421792,
#  253.477215,
#  256.532147,
#  259.583784,
#  262.634854,
#  265.686219,
#  268.742234,
#  271.795455,
#  274.852842,
#  277.903494,
#  280.958558,
#  284.014481,
#  287.061691,
#  290.115716,
#  293.172451,
#  296.223504,
#  299.277101,
#  302.333673,
#  305.386099,
#  308.437495,
#  311.487221,
#  314.538711,
#  317.594036,
#  320.640455,
#  323.694675,
#  326.744198,
#  329.805168,
#  332.853525,
#  335.910564,
#  338.963969,
#  342.018584,
#  345.075009,
#  348.134015,
#  351.185972,
#  354.240948,
#  357.290677,
#  360.336552,
#  363.386178,
#  366.441259,
#  369.492917,
#  372.548987,
#  375.607573,
#  378.658672,
#  381.710269,
#  384.765077,
#  387.818783,
#  390.867461,
#  393.917226,
#  396.974537,
#  400.022707,
#  403.081881,
#  406.133701,
#  409.194318,
#  412.240445,
#  415.293039,
#  418.337714,
#  421.394005,
#  424.445219,
#  427.500321,
#  430.556457,
#  433.608185,
#  436.657143,
#  439.708486,
#  442.764614,
#  445.822719,
#  448.87446,
#  451.929026,
#  454.980533,
#  458.037042,
#  461.091021,
#  464.143697,
#  467.19893,
#  470.257465,
#  473.307447,
#  476.362127,
#  479.415879,
#  482.476716,
#  485.540542,
#  488.635434,
#  491.727865,
#  494.825222,
#  497.914952,
#  501.008814,
#  504.101582,
#  507.200866,
#  510.291378,
#  513.38449,
#  516.478271,
#  519.576441,
#  522.671897,
#  525.766401,
#  528.852881,
#  531.951955,
#  535.042124,
#  538.140137,
#  541.227353,
#  544.322575,
#  547.417848,
#  550.511407,
#  553.604877,
#  556.693133,
#  559.763409,
#  562.820695,
#  565.87266,
#  568.928885,
#  571.980417,
#  575.030496,
#  578.086011,
#  581.137883,
#  584.187021,
#  587.236939,
#  590.290864,
#  593.339527,
#  596.393336,
#  599.441726,
#  602.494889,
#  605.550438,
#  608.604102,
#  611.659248,
#  614.720095,
#  617.77247,
#  620.833557,
#  623.88805,
#  626.943964,
#  630.000746,
#  633.059089,
#  636.119624,
#  639.172118,
#  642.245625,
#  645.310479,
#  648.3709,
#  651.434823,
#  654.497433,
#  657.56031,
#  660.620456,
#  663.679765,
#  666.743701,
#  669.807043,
#  672.867322,
#  675.932765,
#  678.994908,
#  682.059664,
#  685.116148,
#  688.204689,
#  691.295817,
#  694.379948,
#  697.454931,
#  700.534986,
#  703.610723,
#  706.695245,
#  709.7767,
#  712.869698,
#  715.995024,
#  719.116819,
#  722.228533,
#  725.34717,
#  728.455299,
#  731.555062,
#  734.660961,
#  737.761445,
#  740.859203,
#  743.960009,
#  747.069383,
#  750.174684,
#  753.308567,
#  756.471552,
#  759.678318,
#  762.892307,
#  766.077983,
#  769.248944,
#  772.388012,
#  775.533004,
#  778.705983,
#  781.812575,
#  784.894918,
#  787.991996,
#  791.090079,
#  794.200791,
#  797.30272,
#  800.410285,
#  803.520065,
#  806.617488,
#  809.720281,
#  812.813623,
#  815.89987,
#  819.00045,
#  822.110348,
#  825.209121,
#  828.309691,
#  831.424994,
#  834.538366,
#  837.634178,
#  840.75017,
#  843.869627,
#  846.98313,
#  850.107779,
#  853.227769,
#  856.35368,
#  859.462219,
#  862.56438,
#  865.678078,
#  868.794428,
#  871.909699,
#  875.006995,
#  878.110948,
#  881.211015,
#  884.323405,
#  887.429389,
#  890.530159,
#  893.641617,
#  896.765985,
#  899.869593,
#  902.963102,
#  906.049032,
#  909.162246,
#  912.301359,
#  915.435875,
#  918.558159,
#  921.660547,
#  924.752567,
#  927.884097,
#  931.004815,
#  934.100829,
#  937.205616,
#  940.310738,
#  943.403478,
#  946.513471,
#  949.616012,
#  952.714898,
#  955.819156,
#  958.925018,
#  962.059825,
#  965.187192,
#  968.28852,
#  971.395717,
#  974.51442,
#  977.658484,
#  980.775555,
#  983.89095,
#  987.009657,
#  990.120022,
#  993.206687,
#  996.297888,
#  999.478911,
#  1002.581544,
#  1005.678145,
#  1008.780814,
#  1011.867427,
#  1014.949305,
#  1018.029397,
#  1021.108407,
#  1024.200477,
#  1027.294427,
#  1030.385682,
#  1033.483056,
#  1036.579083,
#  1039.678461,
#  1042.763419,
#  1045.897422,
#  1049.058203,
#  1052.315032,
#  1055.544894,
#  1058.770019,
#  1061.989816,
#  1065.194981,
#  1068.405247,
#  1071.595303,
#  1074.763269,
#  1077.999355,
#  1081.147247,
#  1084.312573,
#  1087.42208,
#  1090.523843,
#  1093.623965,
#  1096.714508,
#  1099.823863,
#  1102.928767,
#  1106.049471,
#  1109.15286,
#  1112.246331,
#  1115.308532,
#  1118.366137,
#  1121.447991,
#  1124.548441,
#  1127.645725,
#  1130.737942,
#  1133.831524,
#  1136.935957,
#  1140.042229,
#  1143.152697,
#  1146.260123,
#  1149.368205,
#  1152.465645,
#  1155.570556,
#  1158.672967,
#  1161.768794,
#  1164.868999,
#  1167.968145,
#  1171.077095,
#  1174.184964,
#  1177.302762,
#  1180.42028,
#  1183.512613,
#  1186.624225,
#  1189.729311,
#  1192.840219,
#  1195.955842,
#  1199.071386,
#  1202.176379,
#  1205.291185,
#  1208.403959,
#  1211.506349,
#  1214.603769,
#  1217.710565,
#  1220.790128,
#  1223.835954,
#  1226.89147,
#  1229.944829,
#  1232.99569,
#  1236.048118,
#  1239.094978,
#  1242.144234,
#  1245.192678,
#  1248.246674,
#  1251.298186,
#  1254.345087,
#  1257.396388,
#  1260.443646,
#  1263.490764,
#  1266.540407,
#  1269.594624,
#  1272.64242,
#  1275.690698,
#  1278.741443,
#  1281.791708,
#  1284.845445,
#  1287.899982,
#  1290.941104,
#  1293.990171,
#  1297.044333,
#  1300.090875,
#  1303.139199,
#  1306.190643,
#  1309.243306,
#  1312.292093,
#  1315.34469,
#  1318.395935,
#  1321.443743,
#  1324.499729,
#  1327.554553,
#  1330.606027,
#  1333.656618,
#  1336.706774,
#  1339.758217,
#  1342.80917,
#  1345.859199,
#  1348.909702,
#  1351.954846,
#  1355.004267,
#  1358.057648,
#  1361.10288,
#  1364.150629,
#  1367.201057,
#  1370.248138,
#  1373.302633,
#  1376.352218,
#  1379.407341,
#  1382.453633,
#  1385.504842,
#  1388.559447,
#  1391.61229,
#  1394.665037,
#  1397.71563,
#  1400.769537,
#  1403.815787,
#  1406.868105,
#  1409.912327,
#  1412.957032,
#  1416.00865,
#  1419.057686,
#  1422.109473,
#  1425.157194,
#  1428.205079,
#  1431.25483,
#  1434.30511,
#  1437.358712,
#  1440.414242,
#  1443.466799,
#  1446.519821,
#  1449.568835,
#  1452.62105,
#  1455.672928,
#  1458.726295,
#  1461.779067,
#  1464.829389,
#  1467.878734,
#  1470.927599,
#  1473.977371,
#  1477.031041,
#  1480.08378,
#  1483.134576,
#  1486.187455,
#  1489.228264,
#  1492.280292,
#  1495.335117,
#  1498.383577,
#  1501.436945,
#  1504.487016,
#  1507.535385,
#  1510.58635,
#  1513.637981,
#  1516.689407,
#  1519.743043,
#  1522.792,
#  1525.845555,
#  1528.896422,
#  1531.947554,
#  1534.994503,
#  1538.040484,
#  1541.085704,
#  1544.141012,
#  1547.193837,
#  1550.248108,
#  1553.297048,
#  1556.345763,
#  1559.396064,
#  1562.449651,
#  1565.497319,
#  1568.546937,
#  1571.597332,
#  1574.644983,
#  1577.696563,
#  1580.74437,
#  1583.792776,
#  1586.844593,
#  1589.898483,
#  1592.948876,
#  1596.001078,
#  1599.051838,
#  1602.101216,
#  1605.148345,
#  1608.193896,
#  1611.245697,
#  1614.293085,
#  1617.347354,
#  1620.394528,
#  1623.439099,
#  1626.488111,
#  1629.536554,
#  1632.585019,
#  1635.635211,
#  1638.680698,
#  1641.732779,
#  1644.784738,
#  1647.83093,
#  1650.883138,
#  1653.93388,
#  1656.983195,
#  1660.032167,
#  1663.080795,
#  1666.124558,
#  1669.169501,
#  1672.220008,
#  1675.271402,
#  1678.325356,
#  1681.378985,
#  1684.433022,
#  1687.479874,
#  1690.528367,
#  1693.580952,
#  1696.634785,
#  1699.679515,
#  1702.725661,
#  1705.771494,
#  1708.820936,
#  1711.870083,
#  1714.922667,
#  1717.974129,
#  1721.025831,
#  1724.072364,
#  1727.122353,
#  1730.172966,
#  1733.221941,
#  1736.271729,
#  1739.321558,
#  1742.372512,
#  1745.422556,
#  1748.473422,
#  1751.522714,
#  1754.57131,
#  1757.620185,
#  1760.671359,
#  1763.718534,
#  1766.762608,
#  1769.811931,
#  1772.86103,
#  1775.913644,
#  1778.961374,
#  1782.013599,
#  1785.065735,
#  1788.117678,
#  1791.167593,
#  1794.219523,
#  1797.271149,
#  1800.317352,
#  1803.366067,
#  1806.409135,
#  1809.460924,
#  1812.514029,
#  1815.562307,
#  1818.609605,
#  1821.658216,
#  1824.711493,
#  1827.756099,
#  1830.81008,
#  1833.863186,
#  1836.913629,
#  1839.970187,
#  1843.019715,
#  1846.07648,
#  1849.126106,
#  1852.181481,
#  1855.231817,
#  1858.283722,
#  1861.336278,
#  1864.386327,
#  1867.43527,
#  1870.490026,
#  1873.540701,
#  1876.589744,
#  1879.638171,
#  1882.689661,
#  1885.740676,
#  1888.790511,
#  1891.842111,
#  1894.89378,
#  1897.945387,
#  1900.998825,
#  1904.04977,
#  1907.099422,
#  1910.14367,
#  1913.195515,
#  1916.24437,
#  1919.290322,
#  1922.341584,
#  1925.387913,
#  1928.445592,
#  1931.501593,
#  1934.554099,
#  1937.602386,
#  1940.6513,
#  1943.704076,
#  1946.748944,
#  1949.803839,
#  1952.851197,
#  1955.901725,
#  1958.952659,
#  1962.002076,
#  1965.04816,
#  1968.103863,
#  1971.15675,
#  1974.216008,
#  1977.266119,
#  1980.315061,
#  1983.364062,
#  1986.418279,
#  1989.467118,
#  1992.518049,
#  1995.571401,
#  1998.622756,
#  2001.674718,
#  2004.729707,
#  2007.78019,
#  2010.84035,
#  2013.89501,
#  2016.946105,
#  2019.999117,
#  2023.046641,
#  2026.1033,
#  2029.152112,
#  2032.204658,
#  2035.257446,
#  2038.303144,
#  2041.354987,
#  2044.405513,
#  2047.455441,
#  2050.508514,
#  2053.56198,
#  2056.612906,
#  2059.663886,
#  2062.716497,
#  2065.768708,
#  2068.820487,
#  2071.878997,
#  2074.93565,
#  2077.988398,
#  2081.041554,
#  2084.091311,
#  2087.147433,
#  2090.199501,
#  2093.250404,
#  2096.301817,
#  2099.356138,
#  2102.407241,
#  2105.457943,
#  2108.510827,
#  2111.56318,
#  2114.616985,
#  2117.666136,
#  2120.719183,
#  2123.762073,
#  2126.810926,
#  2129.86455,
#  2132.920801,
#  2135.969898,
#  2139.018999,
#  2142.071592,
#  2145.126264,
#  2148.179108,
#  2151.228978,
#  2154.275356,
#  2157.326303,
#  2160.377387,
#  2163.423232,
#  2166.475399,
#  2169.528904,
#  2172.580949,
#  2175.630463,
#  2178.680931,
#  2181.737093,
#  2184.785491,
#  2187.840967,
#  2190.893165,
#  2193.942934,
#  2196.991174,
#  2200.043325,
#  2203.092808,
#  2206.142587,
#  2209.201422,
#  2212.246022,
#  2215.297458,
#  2218.347115,
#  2221.395977,
#  2224.447821,
#  2227.498471,
#  2230.555671,
#  2233.607945,
#  2236.657362,
#  2239.710489,
#  2242.761738,
#  2245.81509,
#  2248.869739,
#  2251.919709,
#  2254.97741,
#  2258.027698,
#  2261.083136,
#  2264.1323,
#  2267.184914,
#  2270.230152,
#  2273.281088,
#  2276.331531,
#  2279.382147,
#  2282.434773,
#  2285.48707,
#  2288.539074,
#  2291.58538,
#  2294.643326,
#  2297.69173,
#  2300.748016,
#  2303.804508,
#  2306.850729,
#  2309.901168,
#  2312.954431,
#  2316.007108,
#  2319.063478,
#  2322.113762,
#  2325.160858,
#  2328.208608,
#  2331.256214,
#  2334.302535,
#  2337.356774,
#  2340.410592,
#  2343.465342,
#  2346.521697,
#  2349.576752,
#  2352.627601,
#  2355.680305,
#  2358.728353,
#  2361.781852,
#  2364.834179,
#  2367.886819,
#  2370.937571,
#  2373.988557,
#  2377.044143,
#  2380.092714,
#  2383.147048,
#  2386.202597,
#  2389.253411,
#  2392.305508,
#  2395.362149,
#  2398.413182,
#  2401.467454,
#  2404.518945,
#  2407.571019,
#  2410.624564,
#  2413.677887,
#  2416.735144,
#  2419.786768,
#  2422.839377,
#  2425.888982,
#  2428.946519,
#  2431.999459,
#  2435.051044,
#  2438.102707,
#  2441.155329,
#  2444.205589,
#  2447.252418,
#  2450.302074,
#  2453.354893,
#  2456.411768,
#  2459.463429,
#  2462.512502,
#  2465.563274,
#  2468.614233,
#  2471.66469,
#  2474.715701,
#  2477.770265,
#  2480.818521,
#  2483.868012,
#  2486.913294,
#  2489.966816,
#  2493.023664,
#  2496.074021,
#  2499.120597,
#  2502.177727,
#  2505.231042,
#  2508.280266,
#  2511.33265,
#  2514.380408,
#  2517.429667,
#  2520.47844,
#  2523.531174,
#  2526.581427,
#  2529.631753,
#  2532.685072,
#  2535.742893,
#  2538.794652,
#  2541.849281,
#  2544.902746,
#  2547.951256,
#  2551.005223,
#  2554.062716,
#  2557.115289,
#  2560.16836,
#  2563.223192,
#  2566.275237,
#  2569.325403,
#  2572.376055,
#  2575.426622,
#  2578.477128,
#  2581.530446,
#  2584.577166,
#  2587.629884,
#  2590.68198,
#  2593.739219,
#  2596.797562,
#  2599.842711,
#  2602.899159,
#  2605.952195,
#  2609.001611,
#  2612.055112,
#  2615.112107,
#  2618.165307,
#  2621.219202,
#  2624.270693,
#  2627.324066,
#  2630.371302,
#  2633.418483,
#  2636.47103,
#  2639.525301,
#  2642.578279,
#  2645.627228,
#  2648.680004,
#  2651.733746,
#  2654.781352,
#  2657.831902,
#  2660.884865,
#  2663.933917,
#  2666.981849,
#  2670.032784,
#  2673.082407,
#  2676.13159,
#  2679.184803,
#  2682.234766,
#  2685.287047,
#  2688.333573,
#  2691.385872,
#  2694.436524,
#  2697.487951,
#  2700.535609,
#  2703.58656,
#  2706.63469,
#  2709.6885,
#  2712.737412,
#  2715.790659,
#  2718.837792,
#  2721.888786,
#  2724.942126,
#  2727.988866,
#  2731.039141,
#  2734.084477,
#  2737.139522,
#  2740.192236,
#  2743.24561,
#  2746.292017,
#  2749.338955,
#  2752.392204,
#  2755.440014,
#  2758.48811]

# %%
x = np.array(c_num_list)
y_pkeoet_enc = np.array(pkeoet_enc_list)
y_pkeoet_pt = np.array(pkeoet_ptest_list)
y_pkeoet_total = np.array(pkeoet_total_list)
y_dt = np.array(dt_list)
y_pkeet_enc = np.array(pkeet_enc_list)
y_pkeet_t = np.array(pkeet_t_list)

plt.xlabel('Ciphertext Num')
plt.ylabel('Time')

plt.plot(x, y_pkeoet_enc, color='green', label='Pkeoet Enc Time')
plt.plot(x, y_pkeoet_pt, color='yellow', label='Pkeoet PTest Time')
plt.plot(x, y_pkeoet_total, color='black', label='Pkeoet Total Time')
plt.plot(x, y_dt, color='orange', label='Pkeoet DTest Time')
plt.plot(x, y_pkeet_enc, color='red', label='Pkeet Enc Time')
plt.plot(x, y_pkeet_t, color='skyblue', label='Pkeet Test Time')

plt.rcParams['figure.dpi'] = 200
plt.legend()
plt.show()
